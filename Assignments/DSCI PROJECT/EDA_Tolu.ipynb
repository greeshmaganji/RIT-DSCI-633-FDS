# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
import time
from scipy import stats

# %%
df = pd.read_csv("cleanData.csv", index_col = 0)
#df = df.drop(columns=['Unnamed: 0'])

# %%
df_sub = df.loc[:,['Name'] + [f'Bill_{i}' for i in range(1, 311)]]

# %%
df_piv = df_sub.pivot_table( columns='Name',
                     values=[f'Bill_{i}' for i in range(1, 311)], aggfunc='first').reset_index()
df_piv.head()
# Out:
# Name     index a_dutch_ruppersberger abigail_spanberger adam_kinzinger  \
# 0       Bill_1            Not_Voting         Not_Voting            Yea
# 1      Bill_10                   Yea                Yea            Nay
# 2     Bill_100                   Yea                Yea            Nay
# 3     Bill_101                   Yea                Yea            Nay
# 4     Bill_102                   Yea                Yea            Yea
#
# Name adam_schiff adam_smith adrian_smith adriano_espaillat al_green al_lawson  \
# 0     Not_Voting        Yea          Yea               Yea      Yea       Yea
# 1            Yea        Yea          Nay               Yea      Yea       Yea
# 2            Yea        Yea          Nay               Yea      Yea       Yea
# 3            Yea        Yea          Nay               Yea      Yea       Yea
# 4            Yea        Yea          Yea        Not_Voting      Yea       Yea
#
# Name  ... vicky_hartzler victoria_spartz virginia_foxx warren_davidson  \
# 0     ...            Yea             Yea           Yea             Yea
# 1     ...            Nay             Nay           Nay             Nay
# 2     ...            Nay             Nay           Nay             Nay
# 3     ...            Nay             Nay           Nay             Nay
# 4     ...            Yea             Yea           Yea             Yea
#
# Name william_keating william_timmons young_kim yvette_clarke yvette_herrell  \
# 0                Yea             Yea       Yea           Yea            Yea
# 1                Yea             Nay       Nay           Yea            Nay
# 2                Yea             Nay       Nay           Yea            Nay
# 3                Yea             Nay       Nay           Yea            Nay
# 4                Yea             Yea       Yea           Yea            Yea
#
# Name zoe_lofgren
# 0            Yea
# 1            Yea
# 2            Yea
# 3            Yea
# 4            Yea
#
# [5 rows x 439 columns]

# %%
df_sub.head()
# Out:
#                     Name      Bill_1 Bill_2 Bill_3 Bill_4 Bill_5 Bill_6  \
# 0  a_dutch_ruppersberger  Not_Voting    Yea    Yea    Yea    Nay    Yea
# 1     abigail_spanberger  Not_Voting    Yea    Yea    Yea    Nay    Yea
# 2         adam_kinzinger         Yea    Nay    Nay    Nay    Yea    Nay
# 3            adam_schiff  Not_Voting    Yea    Yea    Yea    Nay    Yea
# 4             adam_smith         Yea    Yea    Yea    Yea    Nay    Yea
#
#   Bill_7 Bill_8 Bill_9  ... Bill_301    Bill_302 Bill_303    Bill_304  \
# 0    Yea    Nay    Nay  ...      Yea         Yea      Yea         Yea
# 1    Yea    Nay    Nay  ...      Yea         Yea      Yea         Yea
# 2    Yea    Nay    Nay  ...      Yea  Not_Voting      Nay         Nay
# 3    Yea    Nay    Nay  ...      Yea         Yea      Yea         Yea
# 4    Yea    Nay    Nay  ...      Yea         Yea      Yea  Not_Voting
#
#   Bill_305 Bill_306 Bill_307 Bill_308 Bill_309 Bill_310
# 0      Yea      Yea      Nay      Yea      Yea      Yea
# 0           Yea      Yea      Yea      Nay      Yea      Yea      Yea
# 1           Yea      Yea      Yea      Nay      Yea      Yea      Yea
# 2           Nay      Yea      Yea      Yea      Yea      Yea      Yea
# 3           Yea      Yea      Yea      Nay      Yea      Yea      Yea
# 4    Not_Voting      Yea      Yea      Nay      Yea      Yea      Yea
# ..          ...      ...      ...      ...      ...      ...      ...
# 433         Nay      Yea      Nay      Yea      Nay      Nay      Yea
# 434         Nay      Yea      Yea      Yea      Nay      Yea      Yea
# 435         Yea      Yea      Yea      Nay      Yea      Yea      Yea
# 436         Nay      Yea      Nay      Yea      Nay      Nay      Yea
# 437         Yea      Yea      Yea      Nay      Yea      Yea      Yea
#
# [438 rows x 313 columns]

# %% [markdown]
# - Introduce bernoulli probability model where politicians become columns, bills become rows
# - demonstrates a unique way of seeing who corresponds to which bill with their decision making
#
# - probabilistic clusters: bernoulli mixture model, restricted boltzman machines (probabilistic neural network)

# %%
df.columns
# Out:
# Index(['Name', 'State', 'Party', 'Bill_1', 'Bill_2', 'Bill_3', 'Bill_4',
#        'Bill_5', 'Bill_6', 'Bill_7',
#        ...
#        'Bill_301', 'Bill_302', 'Bill_303', 'Bill_304', 'Bill_305', 'Bill_306',
#        'Bill_307', 'Bill_308', 'Bill_309', 'Bill_310'],
#       dtype='object', length=313)

# %%
df
# Out:
#                       Name           State       Party      Bill_1 Bill_2  \
# 0    a_dutch_ruppersberger        Maryland    Democrat  Not_Voting    Yea
# 1       abigail_spanberger        Virginia    Democrat  Not_Voting    Yea
# 2           adam_kinzinger        Illinois  Republican         Yea    Nay
# 3              adam_schiff      California    Democrat  Not_Voting    Yea
# 4               adam_smith      Washington    Democrat         Yea    Yea
# ..                     ...             ...         ...         ...    ...
# 433        william_timmons  South_Carolina  Republican         Yea    Nay
# 434              young_kim      California  Republican         Yea    Nay
# 435          yvette_clarke        New_York    Democrat         Yea    Yea
# 436         yvette_herrell      New_Mexico  Republican         Yea    Nay
# 437            zoe_lofgren      California    Democrat         Yea    Yea
#
#     Bill_3 Bill_4 Bill_5 Bill_6 Bill_7  ... Bill_301    Bill_302 Bill_303  \
# 0      Yea    Yea    Nay    Yea    Yea  ...      Yea         Yea      Yea
# 1      Yea    Yea    Nay    Yea    Yea  ...      Yea         Yea      Yea
# 2      Nay    Nay    Yea    Nay    Yea  ...      Yea  Not_Voting      Nay
# 3      Yea    Yea    Nay    Yea    Yea  ...      Yea         Yea      Yea
# 4      Yea    Yea    Nay    Yea    Yea  ...      Yea         Yea      Yea
# ..     ...    ...    ...    ...    ...  ...      ...         ...      ...
# 433    Nay    Nay    Yea    Nay    Yea  ...      Yea         Yea      Nay
# 434    Nay    Nay    Yea    Nay    Yea  ...      Yea         Yea      Nay
# 435    Yea    Yea    Nay    Yea    Yea  ...      Yea         Yea      Yea
# 436    Nay    Nay    Yea    Nay    Yea  ...      Yea         Yea      Nay
# 437    Yea    Yea    Nay    Yea    Yea  ...      Yea         Yea      Yea
Yea         Yea         Nay         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Nay         Nay         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Nay         Nay         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Nay         Nay         Yea         Nay         Nay         Yea         Nay         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Nay         Yea         Nay         Yea         Yea         Nay         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Nay         Yea         Nay         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Nay         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea       Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Nay       Yea       Nay       Yea       Yea       Nay       Nay       Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Yea       Yea       Yea       Yea       Yea       Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Nay         Yea         Yea         Nay       Yea       Yea         Yea       Yea       Yea       Nay       Yea       Yea       Nay       Yea       Yea         Yea       Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Nay       Nay       Nay       Nay       Yea       Yea       Yea         Nay         Yea       Nay       Nay       Not_Voting  Nay       Yea       Nay       Yea       Yea       Yea         Nay       Yea       Yea       Nay       Yea       Yea         Yea       Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Nay         Yea       Yea       Yea       Yea         Yea       Yea         Yea       Nay       Yea         Yea       Yea       Yea       Yea       Nay         Yea       Nay       Nay       Yea       Yea       Yea       Yea       Yea       Yea         Yea       Yea       Nay       Yea       Nay       Yea       Yea       Yea         Yea         Yea         Yea         Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Yea       Yea         1
# zoe_lofgren            California  Democrat    Yea         Yea         Yea         Yea         Nay         Yea         Yea         Nay         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Nay         Nay         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Nay         Nay         Nay         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Nay         Nay         Yea         Nay         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Nay         Yea         Nay         Yea         Yea         Nay         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Nay         Yea         Yea         Yea         Yea         Nay         Yea         Nay         Yea         Yea         Nay         Yea         Yea         Yea         Not_Voting  Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Nay         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Nay         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea       Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Nay       Yea       Nay       Yea       Yea       Nay       Yea       Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Yea       Yea       Yea       Yea       Yea       Yea         Yea         Yea         Yea         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Yea         Yea         Nay         Yea         Yea         Nay         Yea         Nay         Yea         Yea         Nay       Yea       Yea         Yea       Yea       Yea       Nay       Yea       Yea       Nay       Yea       Yea         Yea       Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Nay       Nay       Nay       Nay       Yea       Yea       Not_Voting  Nay         Yea       Nay       Nay       Yea         Nay       Yea       Nay       Yea       Yea       Yea         Nay       Yea       Yea       Nay       Yea       Yea         Yea       Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Nay         Yea       Yea       Yea       Yea         Yea       Yea         Yea       Yea       Yea         Yea       Yea       Yea       Yea       Yea         Yea       Yea       Yea       Yea       Yea       Yea       Yea       Yea       Yea         Yea       Yea       Nay       Yea       Nay       Yea       Yea       Not_Voting  Not_Voting  Not_Voting  Not_Voting  Yea       Yea       Yea       Yea       Yea       Yea       Nay       Yea       Yea       Yea         1
# Length: 438, dtype: int64

# %%
#df.Group.value_counts()

# %%
df["Bill_309"].value_counts()
# Out:
# Yea           254
# Nay           174
# Not_Voting      9
# Na              1
# Name: Bill_309, dtype: int64

# %%
df.groupby("Bill_309")["Party"].value_counts()
# Out:
# Bill_309    Party
# Na          Republican      1
# Nay         Republican    174
# Not_Voting  Republican      5
#             Democrat        4
# Yea         Democrat      220
#             Republican     34
# Name: Party, dtype: int64

# %%
sample = df.groupby("Bill_309")["Party"].value_counts()
vote_count = sample
sns.set(style="darkgrid")
sns.barplot(sample.index, sample.values, alpha = 0.5)
plt.title('Frequency Distribution of Bill 118')
plt.ylabel('Number of Occurences', fontsize=10)
plt.xlabel('Bill 118', fontsize=12)
plt.show()

# maybe we should convert what the values are so its just easier all around?
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/fr/03zv9zcj7j146mrr4jsb58kw0000gn/T/ipykernel_97346/2042155864.py in <module>
#       2 vote_count = sample
#       3 sns.set(style="darkgrid")
# ----> 4 sns.barplot(sample.index, sample.values, alpha = 0.5)
#       5 plt.title('Frequency Distribution of Bill 118')
#       6 plt.ylabel('Number of Occurences', fontsize=10)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_core.py in infer_orient(x, y, orient, require_numeric)
#    1309     """
#    1310
# -> 1311     x_type = None if x is None else variable_type(x)
#    1312     y_type = None if y is None else variable_type(y)
#    1313
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_core.py in variable_type(vector, boolean_type)
#    1227
#    1228     # Special-case all-na data, which is always "numeric"
# -> 1229     if pd.isna(vector).all():
#    1230         return "numeric"
#    1231
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     136     Name: 1, dtype: bool
#     137     """
# --> 138     return _isna(obj)
#     139
#     140
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna(obj, inf_as_na)
#     165     # hack (for now) because MI registers as ndarray
#     166     elif isinstance(obj, ABCMultiIndex):
# --> 167         raise NotImplementedError("isna is not defined for MultiIndex")
#     168     elif isinstance(obj, type):
#     169         return False
#
# NotImplementedError: isna is not defined for MultiIndex

# %%
df["Bill_108"].value_counts()
# Out:
# Yea           412
# Not_Voting     17
# Nay             8
# Ye              1
# Name: Bill_108, dtype: int64

# %%
sample = df.groupby("Bill_108")["Party"].value_counts()
vote_count = sample
sns.set(style="darkgrid")
sns.barplot(sample.index, sample.values, alpha = 0.5)
plt.title('Frequency Distribution of Bill 118')
plt.ylabel('Number of Occurences', fontsize=10)
plt.xlabel('Bill 118', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/fr/03zv9zcj7j146mrr4jsb58kw0000gn/T/ipykernel_97346/6438112.py in <module>
#       2 vote_count = sample
#       3 sns.set(style="darkgrid")
# ----> 4 sns.barplot(sample.index, sample.values, alpha = 0.5)
#       5 plt.title('Frequency Distribution of Bill 118')
#       6 plt.ylabel('Number of Occurences', fontsize=10)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_core.py in infer_orient(x, y, orient, require_numeric)
#    1309     """
#    1310
# -> 1311     x_type = None if x is None else variable_type(x)
#    1312     y_type = None if y is None else variable_type(y)
#    1313
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_core.py in variable_type(vector, boolean_type)
#    1227
#    1228     # Special-case all-na data, which is always "numeric"
# -> 1229     if pd.isna(vector).all():
#    1230         return "numeric"
#    1231
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     136     Name: 1, dtype: bool
#     137     """
# --> 138     return _isna(obj)
#     139
#     140
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna(obj, inf_as_na)
#     165     # hack (for now) because MI registers as ndarray
#     166     elif isinstance(obj, ABCMultiIndex):
# --> 167         raise NotImplementedError("isna is not defined for MultiIndex")
#     168     elif isinstance(obj, type):
#     169         return False
#
# NotImplementedError: isna is not defined for MultiIndex

# %%
df.groupby("Bill_180")["Party"].value_counts()
# Out:
# Bill_180    Party
# Na          Republican      1
# Nay         Republican    175
# Not_Voting  Democrat        5
#             Republican      5
# Yea         Democrat      219
#             Republican     33
# Name: Party, dtype: int64

# %%
sample = df.groupby("Bill_180")["Party"].value_counts()
vote_count = sample
sns.set(style="darkgrid")
sns.barplot(sample.index, sample.values, alpha = 0.5)
plt.title('Frequency Distribution of Bill 118')
plt.ylabel('Number of Occurences', fontsize=10)
plt.xlabel('Bill 118', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/fr/03zv9zcj7j146mrr4jsb58kw0000gn/T/ipykernel_97346/4214467972.py in <module>
#       2 vote_count = sample
#       3 sns.set(style="darkgrid")
# ----> 4 sns.barplot(sample.index, sample.values, alpha = 0.5)
#       5 plt.title('Frequency Distribution of Bill 118')
#       6 plt.ylabel('Number of Occurences', fontsize=10)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_core.py in infer_orient(x, y, orient, require_numeric)
#    1309     """
#    1310
# -> 1311     x_type = None if x is None else variable_type(x)
#    1312     y_type = None if y is None else variable_type(y)
#    1313
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_core.py in variable_type(vector, boolean_type)
#    1227
#    1228     # Special-case all-na data, which is always "numeric"
# -> 1229     if pd.isna(vector).all():
#    1230         return "numeric"
#    1231
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     136     Name: 1, dtype: bool
#     137     """
# --> 138     return _isna(obj)
#     139
#     140
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna(obj, inf_as_na)
#     165     # hack (for now) because MI registers as ndarray
#     166     elif isinstance(obj, ABCMultiIndex):
# --> 167         raise NotImplementedError("isna is not defined for MultiIndex")
#     168     elif isinstance(obj, type):
#     169         return False
#
# NotImplementedError: isna is not defined for MultiIndex

# %%
df["Bill_118"].value_counts()
# Out:
# Yea           321
# Nay           100
# Not_Voting     16
# Na              1
# Name: Bill_118, dtype: int64

# %%
df.groupby("Bill_118")["Party"].value_counts()
# Out:
# Bill_118    Party
# Na          Republican      1
# Nay         Republican    100
# Not_Voting  Democrat        9
#             Republican      7
# Yea         Democrat      215
#             Republican    106
# Name: Party, dtype: int64

# %%
sample = df.groupby("Bill_118")["Party"].value_counts()
vote_count = sample
sns.set(style="darkgrid")
sns.barplot(sample.index, sample.values, alpha = 0.5)
plt.title('Frequency Distribution of Bill 118')
plt.ylabel('Number of Occurences', fontsize=10)
plt.xlabel('Bill 118', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/fr/03zv9zcj7j146mrr4jsb58kw0000gn/T/ipykernel_97346/1491153544.py in <module>
#       2 vote_count = sample
#       3 sns.set(style="darkgrid")
# ----> 4 sns.barplot(sample.index, sample.values, alpha = 0.5)
#       5 plt.title('Frequency Distribution of Bill 118')
#       6 plt.ylabel('Number of Occurences', fontsize=10)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_core.py in infer_orient(x, y, orient, require_numeric)
#    1309     """
#    1310
# -> 1311     x_type = None if x is None else variable_type(x)
#    1312     y_type = None if y is None else variable_type(y)
#    1313
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_core.py in variable_type(vector, boolean_type)
#    1227
#    1228     # Special-case all-na data, which is always "numeric"
# -> 1229     if pd.isna(vector).all():
#    1230         return "numeric"
#    1231
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     136     Name: 1, dtype: bool
#     137     """
# --> 138     return _isna(obj)
#     139
#     140
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna(obj, inf_as_na)
#     165     # hack (for now) because MI registers as ndarray
#     166     elif isinstance(obj, ABCMultiIndex):
# --> 167         raise NotImplementedError("isna is not defined for MultiIndex")
#     168     elif isinstance(obj, type):
#     169         return False
#
# NotImplementedError: isna is not defined for MultiIndex

# %% [markdown]
# Rotate the label text —- xticks
#
# https://www.delftstack.com/howto/seaborn/rotate-tick-labels-seaborn/
#
# Consider the following for feature engineering:
#
# df[(df['Party'] == 'Dem') & (df[Bill_2] == 1)]
# df[(df['Party'] == 'Dem') & (df[Bill_2] == 2)]
# max(val1, val2)
# min_val = min(val1, val2)
# df[(df['Party'] == 'Dem') & (df[Bill_2] == min_val)]
#
# min value: # of people who voted agianst their party
#
#
# Take most common value via value_counts
# Do a count where each

# %% [markdown]
# - graphing clusters
# - similarity networks
# - in which issues did democrats' and republicans' votes differ most?
# - principal component analysis? compute distance using Rajski's distance?

# %%
labels = ['Republican', 'Democrat']

colors = sns.color_palette('pastel')[0:5]

plt.pie(df, labels = labels, colors = colors, autopct = '%.0f%')
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fr/03zv9zcj7j146mrr4jsb58kw0000gn/T/ipykernel_97346/1862034853.py in <module>
#       3 colors = sns.color_palette('pastel')[0:5]
#       4
# ----> 5 plt.pie(df, labels = labels, colors = colors, autopct = '%.0f%')
#       6 plt.show
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3004         textprops=None, center=(0, 0), frame=False,
#    3005         rotatelabels=False, *, normalize=None, data=None):
# -> 3006     return gca().pie(
#    3007         x, explode=explode, labels=labels, colors=colors,
#    3008         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3028         # The use of float32 is "historical", but can't be changed without
#    3029         # regenerating the test baselines.
# -> 3030         x = np.asarray(x, np.float32)
#    3031         if x.ndim > 1:
#    3032             raise ValueError("x must be 1D")
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'a_dutch_ruppersberger'

# %%
df["Voter Identification"] =
